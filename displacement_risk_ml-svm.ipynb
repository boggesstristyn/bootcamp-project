# %% [markdown]
# # ETL Section

# %%
# Import dependencies
import pandas as pd

# %%
# Import Displacement CSV data into DataFrame
displacement_df = pd.read_csv('Resources/Displacement_Risk_Demographics_2019.csv', low_memory=False)

# %% [markdown]
# ## Data Exploration

# %%
# Display initial DataFrame
displacement_df.head()
# Out:
#                                             the_geom       GEOID20  \
# 0  MULTIPOLYGON (((-97.74903862358497 30.19139320...  4.850000e+14
# 1  MULTIPOLYGON (((-97.73502862334274 30.25968421...  4.850000e+14
# 2  MULTIPOLYGON (((-97.7167086205077 30.282670219...  4.850000e+14
# 3  MULTIPOLYGON (((-97.64422960245622 30.29935522...  4.850000e+14
# 4  MULTIPOLYGON (((-97.70436961526102 30.22639820...  4.850000e+14
#
#    COUNCIL_DI  Total Population 2020  Total Hispanic Pop 2020  \
# 0           2                     92                       76
# 1           3                     26                       17
# 2           1                     24                        2
# 3           1                     43                       31
# 4           3                     13                        5
#
#    Total NH White 2020  Total NH Black 2020  \
# 0                   15                    0
# 1                    9                    0
# 2                   21                    0
# 3                    4                    5
# 4                    2                    5
#
#    Total NH AM Indian AK Native 2020  Total NH Asian 2020  \
# 0                                  0                    0
# 1                                  0                    0
# 2                                  1                    0
# 3                                  0                    1
# 4                                  0                    0
#
#    Total NH Native Hawaiian 2020  ...  Percent Renter Occupied Units_2019  \
# 0                              0  ...                                0.38
# 1                              0  ...                                0.46
# 2                              0  ...                                0.64
# 3                              0  ...                                0.51
# 4                              0  ...                                0.77
#
#    Percent Owner Occupied Units_2019  Sum of Lowmoduniverse_2019  \
# 0                               0.62                        6065
# 1                               0.54                        3640
# 2                               0.36                        3055
# 3                               0.49                        8490
# 4                               0.23                       10290
#
#    Sum of Lowmod_2019  Percent Lowmod_2019  Median Family Income_2019  \
# 0                4300                 0.71                      56389
# 1                2135                 0.59                      57269
# 2                1705                 0.56                      60950
# 3                6780                 0.80                      44314
# 4                8985                 0.87                      54661
#
#    Median Home Value_2019  Median Gross Rent_2019  Quadrant_2019  \
# 0                  126800                    1579      Southeast
# 1                  440100                    1302           East
# 2                  398200                    1248           East
# 3                   94900                    1211      Northeast
# 4                  207500                     924      Southeast
#
#    Percent severely rent burdened_2019
# 0                                 0.26
# 1                                 0.22
# 2                                 0.33
# 3                                 0.41
# 4                                 0.23
#
# [5 rows x 60 columns]

# %%
# Check shape of initial DataFrame
displacement_df.shape
# Out:
# (3013, 60)

# %%
# List columns of initial DataFrame
displacement_df.columns
# Out:
# Index(['the_geom', 'GEOID20', 'COUNCIL_DI', 'Total Population 2020',
#        'Total Hispanic Pop 2020', 'Total NH White 2020', 'Total NH Black 2020',
#        'Total NH AM Indian AK Native 2020', 'Total NH Asian 2020',
#        'Total NH Native Hawaiian 2020', 'Total NH Other Races 2020',
#        'Total NH Two or More Races 2020', 'Total Housing Units 2020',
#        'Occupied Housing Units 2020', 'Vacant Housing Units 2020', 'GEOID20_1',
#        'Total City Sponsored Affordable Units',
#        'Total Citywide Affordable Units', 'TRACTCE10', 'GEOID10', 'NAME10',
#        'GeoIDNum', 'GEOID_1', 'GEOID1', 'NAME_1', 'GENTRIFICATION Typology',
#        'VULNERABLE Pop', 'DEMOGRAPHIC Change', 'HOUSING_MARKET',
#        'DISPLACEMENT RISK', 'DESCRIPTION', 'FIPS', 'Geographic',
#        'Total_Population_2019', 'White (Not Hispanic)_2019', 'POC%_2019',
#        'White (Not Hispanic)%_2019', 'Population 25 and older_2019',
#        'Education: Less than HS_2019', 'Education: HS Graduate_2019',
#        'Education: Some College_2019', 'Education: Bachelors_2019',
#        'Percent without Bachelors_2019', 'Percent with Bachelors_2019',
#        'Pop under 18 for whom poverty is determined_2019',
#        'Population below poverty_2019', 'Percent Child Poverty_2019',
#        'Occupied Housing Units_2019', 'Owner Occupied Housing Units_2019',
#        'Renter Occupied Housing Units_2019',
#        'Percent Renter Occupied Units_2019',
#        'Percent Owner Occupied Units_2019', 'Sum of Lowmoduniverse_2019',
#        'Sum of Lowmod_2019', 'Percent Lowmod_2019',
#        'Median Family Income_2019', 'Median Home Value_2019',
#        'Median Gross Rent_2019', 'Quadrant_2019',
#        'Percent severely rent burdened_2019'],
#       dtype='object')

# %%
# Check for null values in all columns
displacement_df.isnull().sum()
# Out:
# the_geom                                             0
# GEOID20                                              0
# COUNCIL_DI                                           0
# Total Population 2020                                0
# Total Hispanic Pop 2020                              0
# Total NH White 2020                                  0
# Total NH Black 2020                                  0
# Total NH AM Indian AK Native 2020                    0
# Total NH Asian 2020                                  0
# Total NH Native Hawaiian 2020                        0
# Total NH Other Races 2020                            0
# Total NH Two or More Races 2020                      0
# Total Housing Units 2020                             0
# Occupied Housing Units 2020                          0
# Vacant Housing Units 2020                            0
# GEOID20_1                                            0
# Total City Sponsored Affordable Units                0
# Total Citywide Affordable Units                      0
# TRACTCE10                                            0
# GEOID10                                              0
# NAME10                                               0
# GeoIDNum                                             0
# GEOID_1                                              0
# GEOID1                                               0
# NAME_1                                              41
# GENTRIFICATION Typology                             41
# VULNERABLE Pop                                       0
# DEMOGRAPHIC Change                                  41
# HOUSING_MARKET                                       0
# DISPLACEMENT RISK                                    0
# DESCRIPTION                                          0
# FIPS                                                 0
# Geographic                                           0
# Total_Population_2019                                0
# White (Not Hispanic)_2019                            0
# POC%_2019                                            0
# White (Not Hispanic)%_2019                           0
# Population 25 and older_2019                         0
# Education: Less than HS_2019                         0
# Education: HS Graduate_2019                          0
# Education: Some College_2019                         0
# Education: Bachelors_2019                            0
# Percent without Bachelors_2019                       0
# Percent with Bachelors_2019                          0
# Pop under 18 for whom poverty is determined_2019     0
# Population below poverty_2019                        0
# Percent Child Poverty_2019                           0
# Occupied Housing Units_2019                          0
# Owner Occupied Housing Units_2019                    0
# Renter Occupied Housing Units_2019                   0
# Percent Renter Occupied Units_2019                   0
# Percent Owner Occupied Units_2019                    0
# Sum of Lowmoduniverse_2019                           0
# Sum of Lowmod_2019                                   0
# Percent Lowmod_2019                                  0
# Median Family Income_2019                            0
# Median Home Value_2019                               0
# Median Gross Rent_2019                               0
# Quadrant_2019                                        0
# Percent severely rent burdened_2019                  0
# dtype: int64

# %%
# Check datatypes of columns
displacement_df.dtypes
# Out:
# the_geom                                             object
# GEOID20                                             float64
# COUNCIL_DI                                            int64
# Total Population 2020                                 int64
# Total Hispanic Pop 2020                               int64
# Total NH White 2020                                   int64
# Total NH Black 2020                                   int64
# Total NH AM Indian AK Native 2020                     int64
# Total NH Asian 2020                                   int64
# Total NH Native Hawaiian 2020                         int64
# Total NH Other Races 2020                             int64
# Total NH Two or More Races 2020                       int64
# Total Housing Units 2020                              int64
# Occupied Housing Units 2020                           int64
# Vacant Housing Units 2020                             int64
# GEOID20_1                                           float64
# Total City Sponsored Affordable Units                 int64
# Total Citywide Affordable Units                       int64
# TRACTCE10                                             int64
# GEOID10                                               int64
# NAME10                                              float64
# GeoIDNum                                              int64
# GEOID_1                                               int64
# GEOID1                                                int64
# NAME_1                                               object
# GENTRIFICATION Typology                              object
# VULNERABLE Pop                                       object
# DEMOGRAPHIC Change                                   object
# HOUSING_MARKET                                       object
# DISPLACEMENT RISK                                    object
# DESCRIPTION                                          object
# FIPS                                                  int64
# Geographic                                           object
# Total_Population_2019                                 int64
# White (Not Hispanic)_2019                             int64
# POC%_2019                                           float64
# White (Not Hispanic)%_2019                          float64
# Population 25 and older_2019                          int64
# Education: Less than HS_2019                          int64
# Education: HS Graduate_2019                           int64
# Education: Some College_2019                          int64
# Education: Bachelors_2019                             int64
# Percent without Bachelors_2019                      float64
# Percent with Bachelors_2019                         float64
# Pop under 18 for whom poverty is determined_2019      int64
# Population below poverty_2019                         int64
# Percent Child Poverty_2019                          float64
# Occupied Housing Units_2019                           int64
# Owner Occupied Housing Units_2019                     int64
# Renter Occupied Housing Units_2019                    int64
# Percent Renter Occupied Units_2019                  float64
# Percent Owner Occupied Units_2019                   float64
# Sum of Lowmoduniverse_2019                            int64
# Sum of Lowmod_2019                                    int64
# Percent Lowmod_2019                                 float64
# Median Family Income_2019                             int64
# Median Home Value_2019                                int64
# Median Gross Rent_2019                                int64
# Quadrant_2019                                        object
# Percent severely rent burdened_2019                 float64
# dtype: object

# %%
# Find number of unique geom shapes
displacement_df['the_geom'].nunique()
# Out:
# 3013

# %% [markdown]
# ## Data Cleaning

# %%
# Drop unnecessary columns
displacement_clean_df = displacement_df.drop(['GEOID20',
                                              'GEOID20_1', 
                                              'Total City Sponsored Affordable Units', 
                                              'Total Citywide Affordable Units', 
                                              'GEOID10',  
                                              'GEOID_1', 
                                              'GEOID1', 
                                              'DESCRIPTION',
                                              'FIPS',
                                              'Geographic', 
                                              'Total_Population_2019',
                                              'White (Not Hispanic)_2019',
                                              'POC%_2019',
                                              'Percent without Bachelors_2019', 
                                              'Percent with Bachelors_2019', 
                                              'Percent Renter Occupied Units_2019', 
                                              'Percent Owner Occupied Units_2019', 
                                              'Percent Lowmod_2019', 'TRACTCE10',
                                              'NAME10','GeoIDNum', 'NAME_1',
                                              'the_geom','COUNCIL_DI', 'White (Not Hispanic)_2019',
                                              'Population 25 and older_2019', 'Pop under 18 for whom poverty is determined_2019',
                                              'Percent Child Poverty_2019', 'Occupied Housing Units_2019',
                                              'Owner Occupied Housing Units_2019', 'Renter Occupied Housing Units_2019',
                                              'Sum of Lowmoduniverse_2019', 'Sum of Lowmod_2019',
                                              'Quadrant_2019', 'GENTRIFICATION Typology',
                                              'DISPLACEMENT RISK', 'DEMOGRAPHIC Change', 'HOUSING_MARKET'], axis=1)
displacement_clean_df.head()
# Out:
#    Total Population 2020  Total Hispanic Pop 2020  Total NH White 2020  \
# 0                     92                       76                   15
# 1                     26                       17                    9
# 2                     24                        2                   21
# 3                     43                       31                    4
# 4                     13                        5                    2
#
#    Total NH Black 2020  Total NH AM Indian AK Native 2020  \
# 0                    0                                  0
# 1                    0                                  0
# 2                    0                                  1
# 3                    5                                  0
# 4                    5                                  0
#
#    Total NH Asian 2020  Total NH Native Hawaiian 2020  \
# 0                    0                              0
# 1                    0                              0
# 2                    0                              0
# 3                    1                              0
# 4                    0                              0
#
#    Total NH Other Races 2020  Total NH Two or More Races 2020  \
# 0                          0                                1
# 1                          0                                0
# 2                          0                                0
# 3                          0                                2
# 4                          1                                0
#
#    Total Housing Units 2020  ...  White (Not Hispanic)%_2019  \
# 0                        23  ...                    0.100892
# 1                        17  ...                    0.480611
# 2                        13  ...                    0.508058
# 3                        15  ...                    0.046784
# 4                         1  ...                    0.180042
#
#    Education: Less than HS_2019 Education: HS Graduate_2019  \
# 0                          1650                        1307
# 1                           378                         485
# 2                           241                         568
# 3                          2192                        1634
# 4                           932                         754
#
#    Education: Some College_2019  Education: Bachelors_2019  \
# 0                           636                        270
# 1                           697                       1451
# 2                           431                       1592
# 3                           745                        567
# 4                          1138                       1000
#
#    Population below poverty_2019  Median Family Income_2019  \
# 0                            529                      56389
# 1                              0                      57269
# 2                             50                      60950
# 3                           1628                      44314
# 4                            158                      54661
#
#    Median Home Value_2019  Median Gross Rent_2019  \
# 0                  126800                    1579
# 1                  440100                    1302
# 2                  398200                    1248
# 3                   94900                    1211
# 4                  207500                     924
#
#    Percent severely rent burdened_2019
# 0                                 0.26
# 1                                 0.22
# 2                                 0.33
# 3                                 0.41
# 4                                 0.23
#
# [5 rows x 23 columns]

# %%
# Drop null rows
displacement_clean_df = displacement_clean_df.dropna()

# %%
# Check shape of cleaned DataFrame
displacement_clean_df.shape
# Out:
# (3013, 23)

# %%
# Check datatypes of columns
displacement_clean_df.dtypes
# Out:
# Total Population 2020                    int64
# Total Hispanic Pop 2020                  int64
# Total NH White 2020                      int64
# Total NH Black 2020                      int64
# Total NH AM Indian AK Native 2020        int64
# Total NH Asian 2020                      int64
# Total NH Native Hawaiian 2020            int64
# Total NH Other Races 2020                int64
# Total NH Two or More Races 2020          int64
# Total Housing Units 2020                 int64
# Occupied Housing Units 2020              int64
# Vacant Housing Units 2020                int64
# VULNERABLE Pop                          object
# White (Not Hispanic)%_2019             float64
# Education: Less than HS_2019             int64
# Education: HS Graduate_2019              int64
# Education: Some College_2019             int64
# Education: Bachelors_2019                int64
# Population below poverty_2019            int64
# Median Family Income_2019                int64
# Median Home Value_2019                   int64
# Median Gross Rent_2019                   int64
# Percent severely rent burdened_2019    float64
# dtype: object

# %% [markdown]
# # SQLite Connection

# %%
#import sqlite3

# %%
#conn = sqlite3.connect('gentrification_db.sqlite')

# %%
#displacement_clean_df.to_sql(name='displacement_risk_df', con=conn, if_exists='replace', index=False)

# %% [markdown]
# # Machine Learning Section

# %% [markdown]
#  ## Basic Setup

# %%
# Initial Imports
from pathlib import Path
from collections import Counter
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as skl
import sklearn.metrics as metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, balanced_accuracy_score
from imblearn.metrics import classification_report_imbalanced
from imblearn.combine import SMOTEENN

# %% [markdown]
# ## Preprocess the Dataset

# %%
# Make copy of input DataFrame
df_encoded = displacement_clean_df.copy()
df_encoded.head()
# Out:
#    Total Population 2020  Total Hispanic Pop 2020  Total NH White 2020  \
# 0                     92                       76                   15
# 1                     26                       17                    9
# 2                     24                        2                   21
# 3                     43                       31                    4
# 4                     13                        5                    2
#
#    Total NH Black 2020  Total NH AM Indian AK Native 2020  \
# 0                    0                                  0
# 1                    0                                  0
# 2                    0                                  1
# 3                    5                                  0
# 4                    5                                  0
#
#    Total NH Asian 2020  Total NH Native Hawaiian 2020  \
# 0                    0                              0
# 1                    0                              0
# 2                    0                              0
# 3                    1                              0
# 4                    0                              0
#
#    Total NH Other Races 2020  Total NH Two or More Races 2020  \
# 0                          0                                1
# 1                          0                                0
# 2                          0                                0
# 3                          0                                2
# 4                          1                                0
#
#    Total Housing Units 2020  ...  White (Not Hispanic)%_2019  \
# 0                        23  ...                    0.100892
# 1                        17  ...                    0.480611
# 2                        13  ...                    0.508058
# 3                        15  ...                    0.046784
# 4                         1  ...                    0.180042
#
#    Education: Less than HS_2019 Education: HS Graduate_2019  \
# 0                          1650                        1307
# 1                           378                         485
# 2                           241                         568
# 3                          2192                        1634
# 4                           932                         754
#
#    Education: Some College_2019  Education: Bachelors_2019  \
# 0                           636                        270
# 1                           697                       1451
# 2                           431                       1592
# 3                           745                        567
# 4                          1138                       1000
#
#    Population below poverty_2019  Median Family Income_2019  \
# 0                            529                      56389
# 1                              0                      57269
# 2                             50                      60950
# 3                           1628                      44314
# 4                            158                      54661
#
#    Median Home Value_2019  Median Gross Rent_2019  \
# 0                  126800                    1579
# 1                  440100                    1302
# 2                  398200                    1248
# 3                   94900                    1211
# 4                  207500                     924
#
#    Percent severely rent burdened_2019
# 0                                 0.26
# 1                                 0.22
# 2                                 0.33
# 3                                 0.41
# 4                                 0.23
#
# [5 rows x 23 columns]

# %%
# Encode target variable labels
le = LabelEncoder()
df_encoded["VULNERABLE Pop"] = le.fit_transform(df_encoded["VULNERABLE Pop"])
df_encoded.head(10)
# Out:
#    Total Population 2020  Total Hispanic Pop 2020  Total NH White 2020  \
# 0                     92                       76                   15
# 1                     26                       17                    9
# 2                     24                        2                   21
# 3                     43                       31                    4
# 4                     13                        5                    2
# 5                      0                        0                    0
# 6                    236                      202                   19
# 7                      0                        0                    0
# 8                     32                       15                    0
# 9                    133                       86                   37
#
#    Total NH Black 2020  Total NH AM Indian AK Native 2020  \
# 0                    0                                  0
# 1                    0                                  0
# 2                    0                                  1
# 3                    5                                  0
# 4                    5                                  0
# 5                    0                                  0
# 6                    5                                  0
# 7                    0                                  0
# 8                   13                                  0
# 9                    3                                  0
#
#    Total NH Asian 2020  Total NH Native Hawaiian 2020  \
# 0                    0                              0
# 1                    0                              0
# 2                    0                              0
# 3                    1                              0
# 4                    0                              0
# 5                    0                              0
# 6                    5                              0
# 7                    0                              0
# 8                    0                              0
# 9                    3                              0
#
#    Total NH Other Races 2020  Total NH Two or More Races 2020  \
# 0                          0                                1
# 1                          0                                0
# 2                          0                                0
# 3                          0                                2
# 4                          1                                0
# 5                          0                                0
# 6                          2                                3
# 7                          0                                0
# 8                          3                                1
# 9                          0                                4
#
#    Total Housing Units 2020  ...  White (Not Hispanic)%_2019  \
# 0                        23  ...                    0.100892
# 1                        17  ...                    0.480611
# 2                        13  ...                    0.508058
# 3                        15  ...                    0.046784
# 4                         1  ...                    0.180042
# 5                         0  ...                    0.587016
# 6                        78  ...                    0.323503
# 7                         0  ...                    0.285379
# 8                        11  ...                    0.157380
# 9                        36  ...                    0.177998
#
#    Education: Less than HS_2019  Education: HS Graduate_2019  \
# 0                          1650                         1307
# 1                           378                          485
# 2                           241                          568
# 3                          2192                         1634
# 4                           932                          754
# 5                           259                          417
# 6                           858                         1357
# 7                           521                          463
# 8                           478                          462
# 9                          1655                         1472
#
#    Education: Some College_2019  Education: Bachelors_2019  \
# 0                           636                        270
# 1                           697                       1451
# 2                           431                       1592
# 3                           745                        567
# 4                          1138                       1000
# 5                           684                       2088
# 6                           602                       1429
# 7                           391                        614
# 8                           571                        467
# 9                          1009                       1822
#
#    Population below poverty_2019  Median Family Income_2019  \
# 0                            529                      56389
# 1                              0                      57269
# 2                             50                      60950
# 3                           1628                      44314
# 4                            158                      54661
# 5                             69                      88006
# 6                            947                      48047
# 7                            177                      77829
# 8                             88                      82902
# 9                            814                      63689
#
#    Median Home Value_2019  Median Gross Rent_2019  \
# 0                  126800                    1579
# 1                  440100                    1302
# 2                  398200                    1248
# 3                   94900                    1211
# 4                  207500                     924
# 5                  338300                    1319
# 6                  346400                    1136
# 7                  211300                    1422
# 8                  201700                    1319
# 9                  201300                    1028
#
#    Percent severely rent burdened_2019
# 0                                 0.26
# 1                                 0.22
# 2                                 0.33
# 3                                 0.41
# 4                                 0.23
# 5                                 0.26
# 6                                 0.37
# 7                                 0.25
# 8                                 0.29
# 9                                 0.24
#
# [10 rows x 23 columns]

# %%
# Perform Covariance Analysis between Input Variables and Target Variable
fig, ax = plt.subplots(figsize=(14,14))
corr =  df_encoded.corr(method='pearson')
trimask_u = np.triu(np.ones_like(corr, dtype=bool))
trimask_l = np.tril(np.ones_like(corr, dtype=bool))
hmap=sns.heatmap(corr, mask = trimask_u, cmap="rocket")

# %%
# Segment the features from the target variable
y = df_encoded["VULNERABLE Pop"]
X = df_encoded.drop(columns="VULNERABLE Pop")

# %%
# Drop Target Variable from DataFrame
df_encoded = df_encoded.drop(["VULNERABLE Pop"], axis=1)
df_encoded.head()
# Out:
#    Total Population 2020  Total Hispanic Pop 2020  Total NH White 2020  \
# 0                     92                       76                   15
# 1                     26                       17                    9
# 2                     24                        2                   21
# 3                     43                       31                    4
# 4                     13                        5                    2
#
#    Total NH Black 2020  Total NH AM Indian AK Native 2020  \
# 0                    0                                  0
# 1                    0                                  0
# 2                    0                                  1
# 3                    5                                  0
# 4                    5                                  0
#
#    Total NH Asian 2020  Total NH Native Hawaiian 2020  \
# 0                    0                              0
# 1                    0                              0
# 2                    0                              0
# 3                    1                              0
# 4                    0                              0
#
#    Total NH Other Races 2020  Total NH Two or More Races 2020  \
# 0                          0                                1
# 1                          0                                0
# 2                          0                                0
# 3                          0                                2
# 4                          1                                0
#
#    Total Housing Units 2020  ...  White (Not Hispanic)%_2019  \
# 0                        23  ...                    0.100892
# 1                        17  ...                    0.480611
# 2                        13  ...                    0.508058
# 3                        15  ...                    0.046784
# 4                         1  ...                    0.180042
#
#    Education: Less than HS_2019  Education: HS Graduate_2019  \
# 0                          1650                         1307
# 1                           378                          485
# 2                           241                          568
# 3                          2192                         1634
# 4                           932                          754
#
#    Education: Some College_2019  Education: Bachelors_2019  \
# 0                           636                        270
# 1                           697                       1451
# 2                           431                       1592
# 3                           745                        567
# 4                          1138                       1000
#
#    Population below poverty_2019  Median Family Income_2019  \
# 0                            529                      56389
# 1                              0                      57269
# 2                             50                      60950
# 3                           1628                      44314
# 4                            158                      54661
#
#    Median Home Value_2019  Median Gross Rent_2019  \
# 0                  126800                    1579
# 1                  440100                    1302
# 2                  398200                    1248
# 3                   94900                    1211
# 4                  207500                     924
#
#    Percent severely rent burdened_2019
# 0                                 0.26
# 1                                 0.22
# 2                                 0.33
# 3                                 0.41
# 4                                 0.23
#
# [5 rows x 22 columns]

# %%
# Check datatypes of columns
df_encoded.dtypes
# Out:
# Total Population 2020                    int64
# Total Hispanic Pop 2020                  int64
# Total NH White 2020                      int64
# Total NH Black 2020                      int64
# Total NH AM Indian AK Native 2020        int64
# Total NH Asian 2020                      int64
# Total NH Native Hawaiian 2020            int64
# Total NH Other Races 2020                int64
# Total NH Two or More Races 2020          int64
# Total Housing Units 2020                 int64
# Occupied Housing Units 2020              int64
# Vacant Housing Units 2020                int64
# VULNERABLE Pop                           int32
# White (Not Hispanic)%_2019             float64
# Education: Less than HS_2019             int64
# Education: HS Graduate_2019              int64
# Education: Some College_2019             int64
# Education: Bachelors_2019                int64
# Population below poverty_2019            int64
# Median Family Income_2019                int64
# Median Home Value_2019                   int64
# Median Gross Rent_2019                   int64
# Percent severely rent burdened_2019    float64
# dtype: object

# %%
# Use the train_test_split function to create training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
# Check shape of training subset
X_train.shape
# Out:
# (2259, 22)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# View scaled training data
X_train_scaled
# Out:
# array([[-0.4804838 , -0.39975421, -0.4787331 , ..., -0.31605415,
#         -0.98065087, -0.26137463],
#        [-0.4804838 , -0.39975421, -0.4787331 , ..., -1.40205438,
#          0.0257483 ,  1.06141523],
#        [-0.25990195, -0.34523757, -0.17488365, ...,  0.4339548 ,
#         -3.57045139, -1.94492536],
#        ...,
#        [-0.4804838 , -0.39975421, -0.4787331 , ...,  0.23411165,
#         -0.4573233 , -0.26137463],
#        [-0.4804838 , -0.39975421, -0.4787331 , ..., -0.05171978,
#         -0.55125389,  0.9411616 ],
#        [-0.35376657, -0.31408521, -0.37744995, ...,  0.23411165,
#         -0.4573233 , -0.26137463]])

# %%
# Test for class imbalance of target variable
Counter(y_train)
# Out:
# Counter({1: 1650, 0: 609})

# %% [markdown]
#  ## Basic SVM Model

# %%
# Initilize a linear SVM model
model = SVC(kernel='rbf', probability=True)

# %%
# Fit our model with the training data
model.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True)

# %%
# Make predictions using the test data
y_pred = model.predict(X_test_scaled)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(10)
# Out:
#    Prediction  Actual
# 0           0       0
# 1           1       1
# 2           1       1
# 3           1       1
# 4           1       1
# 5           1       1
# 6           1       1
# 7           1       1
# 8           1       1
# 9           1       1

# %% [markdown]
# ### Assess Performance of Basic SVM Model

# %%
# Calculate the Balanced Accuracy Score
svc_score = balanced_accuracy_score(y_test, y_pred)
print(svc_score)
# Out:
# 0.9891107078039927

# %%
# Generate Confusion Matrix
matrix = confusion_matrix(y_test, y_pred)
matrix_df = pd.DataFrame(matrix, index=["Actual 0", "Actual 1"],
                        columns=["Predicted 0", "Predicted 1"])
display(matrix_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0          203            0
# Actual 1           12          539

# %%
# Generate Classification Report
report = classification_report_imbalanced(y_test, y_pred)
print(report)
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.94      1.00      0.98      0.97      0.99      0.98       203
#           1       1.00      0.98      1.00      0.99      0.99      0.98       551
#
# avg / total       0.98      0.98      0.99      0.98      0.99      0.98       754

# %% [markdown]
# ### ROC Curve for Basic SVM Model

# %%
# Calculate the fpr and tpr Basic SVM Model
probs = model.predict_proba(X_test_scaled)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)
print(roc_auc)
# Out:
# 0.9963165941011863

# %%
# Graph ROC Curve
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1.05])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## SVM Model - Combination Sampling

# %%
# Use SMOTEEN to correct class imbalance with resampling
smote_enn = SMOTEENN(random_state=1)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

# Test for class imbalance of target variable
Counter(y_resampled)
# Out:
# Counter({0: 2201, 1: 2201})

# %%
# Fit our model with the resampled training data
model_smote_svm = SVC(kernel='rbf')

model_smote_svm.fit(X_resampled, y_resampled)
# Out:
# SVC()

# %%
# Make predictions using the unscaled test data
y_pred = model_smote_svm.predict(X_test)

# %% [markdown]
# ### Assess Performance of SMOTEEN SVM Model

# %%
# Calculate the Balanced Accuracy Score
svcsmote_score = balanced_accuracy_score(y_test, y_pred)
print(svcsmote_score)
# Out:
# 0.9455535390199636

# %%
# Generate Confusion Matrix
matrix = confusion_matrix(y_test, y_pred)
matrix_df = pd.DataFrame(matrix, index=["Actual 0", "Actual 1"],
                        columns=["Predicted 0", "Predicted 1"])
display(matrix_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0          203            0
# Actual 1           60          491

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.77      1.00      0.89      0.87      0.94      0.90       203
#           1       1.00      0.89      1.00      0.94      0.94      0.88       551
#
# avg / total       0.94      0.92      0.97      0.92      0.94      0.89       754

# %% [markdown]
# # Results Summary

# %%
# Generate summary DataFrame
results_data = {'Balanced Accuracy Score' : [svc_score, svcsmote_score]}
results_table = pd.DataFrame(data=results_data, index=["Basic SVC Model", "SVC Model with SMOTEEN"])
display(results_table)
# Out:
#                         Balanced Accuracy Score
# Basic SVC Model                        0.989111
# SVC Model with SMOTEEN                 0.945554
